# %%
# %matplotlib inline
# %matplotlib notebook
import numpy as np, matplotlib.pyplot as plt
import pyregion
from astropy.io import fits
from PyMUSE.musecube import MuseCube
# Out:
# WARNING: AstropyDeprecationWarning: block_reduce was moved to the astropy.nddata.blocks module.  Please update your import statement. [astropy.nddata.utils]

# %%
filename_cube = '/home/pc/Escritorio/SIT45/Cubos/SIT45B/ADP.2019-10-08T16_15_37.213-003.fits'
filename_white = '/home/pc/white_SIT45B.fits'
cube = MuseCube(filename_cube, filename_white, input_wave_cal='air', output_wave_cal = 'vac')
# Out:
# MuseCube: Loading the cube fluxes and variances...
# <img src="data:image/png;base64,..." width="432">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# MuseCube: Ready!

# %%
ds9reg_filename = '/home/pc/Escritorio/SIT45/Cubos/SIT45B/SIT45_B_RP1.reg'
spectrum = cube.get_spec_from_ds9regfile(ds9reg_filename,mode='wwm')
#spectrum.plot()

# %%
# %matplotlib inline
ha_line, z, delta = 6562.80, 0.034, 11.
ha_obs = ha_line*(1.+z)

print(ha_obs-5, ha_obs+5)

halpha = cube.get_image([[ha_obs-delta,ha_obs+delta]], fitsname='SIT45B-Halpha.fits', type='sum', n_figure=1, save=True, stat=False, inverse_mask=region_name)

plt.imshow(np.arcsinh(halpha), origin='lower', cmap='viridis')
# Out:
# 6780.935200000001 6790.935200000001
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to -5.418e+02 [aplpy.core]
# INFO: Auto-setting vmax to  5.070e+03 [aplpy.core]

# %%
region_string = """
# Region file format: DS9 version 4.1
# Filename: test01.fits
global color=green dashlist=8 3 width=1 font="helvetica 10 normal" select=1 highlite=1 dash=0 fixed=0 edit=1 move=1 delete=1 include=1 source=1
fk5
circle(11:24:24.230,-59:15:02.20,18.5108") # color=cyan background
box(11:24:39.213,-59:16:53.91,42.804",23.616",19.0384) # width=4
"""

r = pyregion.parse(region_string)

# %%
f = fits.open("SIT45B-Halpha.fits")
region_name = "/home/pc/Escritorio/SIT45/Cubos/SIT45B/SIT45_B_RP1.reg"
r = pyregion.open(region_name)
r[0]
# Out:
# Shape : circle ( HMS(23:25:02.8430),DMS(+0:00:30.563),Ang(1.340") )

# %%
r = pyregion.parse(region_string).as_imagecoord(f[0].header)
patch_list, artist_list = r.get_mpl_patches_texts()
# Out:
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 ' / Coordinate system
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: The WCS transformation has more axes (2) than the image it is associated with (0) [astropy.wcs.wcs]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7d8412d6183f> in <module>
# ----> 1 r = pyregion.parse(region_string).as_imagecoord(f[0].header)
#       2 patch_list, artist_list = r.get_mpl_patches_texts()
#
# ~/.local/lib/python3.8/site-packages/pyregion/core.py in as_imagecoord(self, header)
#      68         r = RegionParser.sky_to_image(zip(self, comment_list),
#      69                                       header)
# ---> 70         shape_list, comment_list = zip(*list(r))
#      71         return ShapeList(shape_list, comment_list=comment_list)
#      72
#
# ...

# %%
cube.get_image(wv_input=[[ha_obs-delta,ha_obs+delta]],maskfile='/home/pc/Escritorio/SIT45/Cubos/SIT45B/SIT45_B_RP1.reg',save=True,inverse_mask=True)
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to  0.000e+00 [aplpy.core]
# INFO: Auto-setting vmax to  0.000e+00 [aplpy.core]
# /home/pc/.local/lib/python3.8/site-packages/astropy/visualization/mpl_normalize.py:164: RuntimeWarning: invalid value encountered in true_divide
#   np.true_divide(values, self.vmax - self.vmin, out=values)
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# ...

# %%
#SIT45_B_R1
spectrum1 = cube.get_spec_from_ellipse_params(162,264,[10,10,0], mode='wwm', save=True, color='blue')
#spec = cube.get_spec_from_ellipse_params(162,264,4,color='Blue')
#spectrum1.plot()
# Out:
# normalization factor relative to total flux = 308.43813432651655
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="636">
# Wrote spectrum to J232502.81+000030.7.fits

# %%
#SIT45_B_R2
spectrum2 = cube.get_spec_from_ellipse_params(300,175,[5,5,0], mode='wwm', save=True, color='gold')
#spec = cube.get_spec_from_ellipse_params(162,264,4,color='Blue')
#spectrum2.plot()
# Out:
# normalization factor relative to total flux = 80.08135846983214
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="664">
# Wrote spectrum to J232500.97+000012.9.fits

# %%
#SIT45_B_R3
spectrum3 = cube.get_spec_from_ellipse_params(243,275,[6,6,0], mode='wwm', save=True, color='white')
#spec = cube.get_spec_from_ellipse_params(162,264,4,color='Blue')
#spectrum3.plot()
# Out:
# normalization factor relative to total flux = 113.02701095382666
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="589.3333333333334">
# Wrote spectrum to J232501.73+000032.9.fits

# %%
#SIT45_B_R4
spectrum4 = cube.get_spec_from_ellipse_params(189,244,[5,5,0], mode='wwm', save=True, color='violet')
#spec = cube.get_spec_from_ellipse_params(162,264,4,color='Blue')
#spectrum4.plot()
# Out:
# normalization factor relative to total flux = 80.88364266766912
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="604">
# Wrote spectrum to J232502.45+000026.7.fits

# %%
imagen=cube.get_image_wv_ranges([[6775,6895]],save=True,substract_cont=True,fitsname='new_collapsed_cube.fits')
# Out:
# /home/pc/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# <img src="data:image/png;base64,..." width="432">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to -8.783e+02 [aplpy.core]
# INFO: Auto-setting vmax to  6.543e+03 [aplpy.core]

# %%
# %matplotlib notebook
plt.imshow((imagen), origin='lower')
# Out:
# <ipython-input-45-ef42a2320a51>:2: RuntimeWarning: overflow encountered in sinh
#   plt.imshow(np.sinh(imagen), origin='lower')
# <img src="data:image/png;base64,..." width="432">
