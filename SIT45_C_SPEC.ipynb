# %%
# %matplotlib inline
# %matplotlib notebook
import numpy as np, matplotlib.pyplot as plt
import pyregion
from astropy.io import fits
from PyMUSE.musecube import MuseCube

# %%
filename_cube = '/home/pc/Escritorio/AyInv1s2021/MUSE/ADP.2019-10-10T20_13_38.022-002.fits'
filename_white = '/home/pc/white_SIT45C.fits'
cube = MuseCube(filename_cube, filename_white, input_wave_cal='air', output_wave_cal = 'vac')
# Out:
# MuseCube: Loading the cube fluxes and variances...
# <img src="data:image/png;base64,..." width="432">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# MuseCube: Ready!

# %%
#SIT45_C_R1
spectrum1 = cube.get_spec_from_ellipse_params(234,14,[5,5,0], mode='wwm',save=True, color='Red')
#spectrum1.plot()
# Out:
# normalization factor relative to total flux = 72.65507396562889
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="622">
# Wrote spectrum to J232502.83+000031.0.fits

# %%
#SIT45_C_R2
spectrum2 = cube.get_spec_from_ellipse_params(245,80,[8,8,0], mode='wwm', save=True, color='Blue')
#spectrum2.plot()
# Out:
# normalization factor relative to total flux = 195.55543895271552
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="595.3333333333334">
# Wrote spectrum to J232502.69+000044.2.fits

# %%
#SIT45_C_R3
spectrum3 = cube.get_spec_from_ellipse_params(284,100,[7,7,0], mode='wwm', save=True, color='yellow')
#spectrum3.plot()
# Out:
# normalization factor relative to total flux = 148.32499254933225
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="634">
# Wrote spectrum to J232502.17+000048.2.fits

# %%
#SIT45_C_R4
spectrum4 = cube.get_spec_from_ellipse_params(217,112,[5,5,0], mode='wwm', save=True, color='orange')
#spectrum4.plot()
# Out:
# normalization factor relative to total flux = 80.87183586354924
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="614">
# Wrote spectrum to J232503.06+000050.6.fits

# %%
#SIT45_C_R5
spectrum5 = cube.get_spec_from_ellipse_params(238,114,[5,5,0], mode='wwm', save=True, color='cyan')
#spectrum5.plot()
# Out:
# normalization factor relative to total flux = 81.03054108541608
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="619.3333333333334">
# Wrote spectrum to J232502.78+000051.0.fits

# %%
#SIT45_C_R6
spectrum6 = cube.get_spec_from_ellipse_params(261,142,[5,5,0], mode='wwm', save=True, color='green')
#spectrum6.plot()
# Out:
# normalization factor relative to total flux = 79.39635697490164
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="660">
# Wrote spectrum to J232502.47+000056.6.fits

# %%
#SIT45_C_R7
spectrum7 = cube.get_spec_from_ellipse_params(288,206,[5,5,0], mode='wwm', save=True, color='pink')
#spectrum7.plot()
# Out:
# normalization factor relative to total flux = 80.18013148111828
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="648">
# Wrote spectrum to J232502.11+000109.4.fits
