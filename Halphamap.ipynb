# %%
# %matplotlib notebook
import numpy as np, matplotlib.pyplot as plt
import matplotlib.colors as colors
from astropy.io import fits
import matplotlib.colors as colors
import montage_wrapper as montage
from IPython.display import Image
from PyMUSE.musecube import MuseCube
# Out:
# WARNING: AstropyDeprecationWarning: block_reduce was moved to the astropy.nddata.blocks module.  Please update your import statement. [astropy.nddata.utils]

# %%
cube1 = MuseCube('/home/pc/Escritorio/AyInv1s2021/MUSE/ADP.2019-10-08T16_15_37.213-003.fits','/home/pc/white_SIT45B.fits')
# Out:
# MuseCube: Loading the cube fluxes and variances...
# <img src="data:image/png;base64,..." width="640">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# MuseCube: Ready!

# %%
ha_line, z, delta = 6562.80, 0.034, 20.
ha_obs = ha_line*(1.+z)

print(ha_obs-20, ha_obs+20)

#image = image[halpha].sum(axis=0) # Collapse in the H_alpha wavelength range
#plt.figure(4)
#plt.imshow(np.log10(image), origin='lower', extent=extent, cmap=sauron)
#plt.colorbar()
#plt.title(r'$\rm log(H_\alpha)$', size=16)
#plt.xlabel(r'$\rm x\ [arcsec]$', size=16)
#plt.ylabel(r'$\rm y\ [arcsec]$', size=16)
#plt.savefig('7495-12703_map_logHalpha_margudo.png')
# Out:
# 6765.935200000001 6805.935200000001

# %%
image1 = cube1.get_image([[ha_obs-delta,ha_obs+delta]], fitsname='SIT45B-Halpha.fits', 
                         type='sum', n_figure=1, save=True, stat=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-aec58c7f92a0> in <module>
# ----> 1 image1 = cube1.get_image([[ha_obs-delta,ha_obs+delta]], fitsname='SIT45B-Halpha.fits',
#       2                          type='sum', n_figure=1, save=True, stat=True)
#       3
#
# NameError: name 'cube1' is not defined

# %%
image2=cube1.get_image_wv_ranges([[6778, 6798]],save=True,
                                 substract_cont=True,fitsname='SIT45B-Halpha-SC.fits',n_figure=2)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# <img src="data:image/png;base64,..." width="640">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to -4.449e+02 [aplpy.core]
# INFO: Auto-setting vmax to  3.649e+03 [aplpy.core]

# %%
#n_figure=9
# %matplotlib notebook
plt.imshow(np.arcsinh(image2), origin='lower', cmap='gist_rainbow')
#plt.imshow(image2, vmin=np.nanmean(image2)-1*np.nanstd(image2),vmax=np.nanmean(image2)+1*np.nanstd(image2), origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
spectrum1 = cube1.get_spec_from_ellipse_params(239,277,[15,26,120], 
                                               mode='sum', save=True, color='red',n_figure=4)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="920">
# Wrote spectrum to J232501.79+000033.3.fits

# %%
spectrum2 = cube1.get_spec_from_ellipse_params(177,255,[42,13,140], 
                                               mode='sum', save=True, color='brown',n_figure=5)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="890">
# Wrote spectrum to J232502.61+000028.9.fits

# %%
spectrum3 = cube1.get_spec_from_ellipse_params(243,275,[6,6,0], mode='sum', save=True, color='fuchsia',n_figure=6)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="640">
# Wrote spectrum to J232501.73+000032.9.fits

# %%
cube2 = MuseCube('/home/pc/Escritorio/AyInv1s2021/MUSE/ADP.2019-10-10T20_13_38.022-002.fits','/home/pc/white_SIT45C.fits')
# Out:
# MuseCube: Loading the cube fluxes and variances...
# <img src="data:image/png;base64,..." width="640">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# MuseCube: Ready!

# %%
image7 = cube2.get_image([[ha_obs-delta,ha_obs+delta]], 
                         fitsname='SIT45C-Halpha.fits', type='sum', save=True, stat=True, n_figure=7)
# Out:
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# <img src="data:image/png;base64,..." width="640">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to -4.366e+02 [aplpy.core]
# INFO: Auto-setting vmax to  4.847e+03 [aplpy.core]

# %%
image8=cube2.get_image_wv_ranges([[6778, 6798]],save=True,
                                 substract_cont=True,fitsname='SIT45C-Halpha-SC.fits',n_figure=8)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1113: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# WARNING: AstropyDeprecationWarning: "clobber" was deprecated in version 2.0 and will be removed in a future version. Use argument "overwrite" instead. [PyMUSE.musecube]
# <img src="data:image/png;base64,..." width="640">
# WARNING: hdu=0 does not contain any data, using hdu=1 instead [aplpy.core]
# INFO: Auto-setting vmin to -2.100e+02 [aplpy.core]
# INFO: Auto-setting vmax to  1.238e+03 [aplpy.core]

# %%
#n_figure=9
# %matplotlib notebook
plt.imshow(np.arcsinh(image8), origin='lower', cmap='gist_rainbow')
#plt.imshow(image8, vmin=np.nanmean(image8)-1*np.nanstd(image8), vmax=np.nanmean(image8)+1*np.nanstd(image8), origin='lower')
# Out:
# <img src="data:image/png;base64,..." width="682">

# %%
spectrum4 = cube2.get_spec_from_ellipse_params(232,100,[15,32,115], mode='sum',save=True, color='Red', n_figure=10)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="745.3333333333334">
# Wrote spectrum to J232502.86+000048.2.fits

# %%
spectrum5 = cube2.get_spec_from_ellipse_params(265,133,[50,12,120], mode='sum',save=True, color='magenta', n_figure=11)
# Out:
# /home/pc/.local/lib/python3.8/site-packages/linetools/spectra/xspectrum1d.py:107: UserWarning: Assuming wavelength unit is Angstroms
#   warnings.warn("Assuming wavelength unit is Angstroms")
# <img src="data:image/png;base64,..." width="675.3333333333334">
# Wrote spectrum to J232502.42+000054.8.fits

# %%
#ima = fits.open('/home/pc/Escritorio/AyInv1s2021/MUSE/img/SIT45C-Halpha-SC.fits','/home/pc/Escritorio/AyInv1s2021/MUSE/img/SIT45B-Halpha-SC.fits')
path_ima = '/home/pc/Escritorio/AyInv1s2021/MUSE/img/r'

# %%
#extracts the FITS header geometry information from a set of files and creates an ASCII 
#image metadata table which is used by several of the other programs
montage.mImgtbl(directory=path_ima, images_table='images_maic.tbl')

#generates the FITS header that best describes the output image.
montage.mMakeHdr('images_maic.tbl', 'template_maic.hdr', north_aligned=True)
# Out:
# stat : OK
# module : mMakeHdr
# msg : Cube columns exist but are either blank or inconsistent. Outputting 2D only.
# count : 2
# ncube : 0
# naxis1 : 396
# naxis2 : 570
# clon : 351.263877
# clat : 0.009684
# lonsize : 0.022
# latsize : 0.031667
# posang : 0.0
# lon1 : 351.274877
# lat1 : -0.006149
# lon2 : 351.252877
# lat2 : -0.006149
# lon3 : 351.252877
# lat3 : 0.025518
# lon4 : 351.274877
# lat4 : 0.025518

# %%
montage.mosaic(path_ima, path_ima+'/median', header='template_maic.hdr',background_match=True, combine='median')
# Out:
# INFO: Listing raw frames [montage_wrapper.wrappers]
# INFO: Checking for coverage [montage_wrapper.wrappers]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-53bae0f99c21> in <module>
# ----> 1 montage.mosaic(path_ima, path_ima+'/median', header='template_maic.hdr',background_match=True, combine='median')
#
# ~/src/montage-wrapper/montage_wrapper/wrappers.py in mosaic(input_dir, output_dir, header, image_table, mpi, n_proc, background_match, imglist, combine, exact_size, cleanup, bitpix, level_only, work_dir, background_n_iter, subset_fast, hdu)
#     536     else:
#     537         log.info("Checking for coverage")
# --> 538         s = m.mSubset(images_raw_all_tbl, header_hdr, images_raw_tbl, fast_mode=subset_fast)
#     539         if s.nmatches == 0:
#     540             raise MontageError("No images overlap with the requested header")
#
# ...

# %%
ima = fits.open('/home/pc/Escritorio/AyInv1s2021/MUSE/img/mosaic.fits')
image = ima[0].data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-d3a946623aed> in <module>
# ----> 1 ima = fits.open('/home/pc/Escritorio/AyInv1s2021/MUSE/img/mosaic.fits')
#       2 image = ima[0].data
#
# ~/.local/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     171         raise ValueError(f'Empty filename: {name!r}')
#     172
# --> 173     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     174                             lazy_load_hdus, ignore_missing_simple, **kwargs)
#     175
#
# ~/.local/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     406         """
#     407
# ...

# %%
plt.figure(1,figsize=(7,7))
plt.imshow(np.arcsinh(image), origin='lower')#, vmin=np.nanmin(np.arcsinh(image)), 
          # vmax=np.nanmax(np.arcsinh(image)))
plt.xlabel(r'$\rm \Delta \alpha \, [pixels]$', fontsize=16)
plt.ylabel(r'$\rm \Delta \delta \, [pixels]$', fontsize=16)
plt.savefig('SIT45_MUSE_Halpha.png')

# %%
# %matplotlib notebook
plt.figure(1,figsize=(7,7))
plt.imshow(np.arcsinh(image), origin='lower', 
           vmin=np.nanmin(np.arcsinh(image)+8), vmax=np.nanmax(np.arcsinh(image)))
plt.xlabel(r'$\rm \Delta \alpha \, [pixels]$', fontsize=16)
plt.ylabel(r'$\rm \Delta \delta \, [pixels]$', fontsize=16)
plt.savefig('SIT45_MUSE_Halpha.png')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
imagen=cube2.get_image_wv_ranges([[6773, 6803]],save=True,substract_cont=True,fitsname='SIT45C-Halpha-SC.fits')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c22662de0084> in <module>
# ----> 1 imagen=cube2.get_image_wv_ranges([[6773, 6803]],save=True,substract_cont=True,fitsname='SIT45C-Halpha-SC.fits', stat=True)
#
# TypeError: get_image_wv_ranges() got an unexpected keyword argument 'stat'
