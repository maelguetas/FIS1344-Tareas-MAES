# %% [markdown]
# ## Tarea #3.5
# ## FIS1344 - Métodos númericos y probabilidades
# ## Marcos Ausgusto Elgueta Salas
#
# Suponga que usted es un ayudante de un laboratorio de física. En un experimento se pide medir la posición de una masa que cae en un plano inclinado a intervalos regulares en el tiempo. El equipo disponible puede medir las posiciones con una precisión de $4\,\text{mm}$. Uno de los estudiantes usa los siguientes datos (en $\text{cm}$):

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
datos = [0.9,  2. ,  3.6,  5.6,  8. , 10.9, 14.2, 18.]

# %% [markdown]
# Grafique estos datos con sus barras de error. Explique por qué el estudiante merece una nota de 1.0. Compare con los siguientes datos obtenidos por un estudiante que merece 7.0.

# %%
datos_7 = [0.3,  1.7,  4.1,  5.7,  8.5, 10.7, 13.6, 17.2]

# %% [markdown]
# ### Gráfico para estudiante con nota 1:

# %%
y = np.array(datos)
dy=[0.4,  0.4,  0.4,  0.4,  0.4, 0.4, 0.4, 0.4]# 4mm en cm -> 0.4cm 
ey=np.array(dy)
    

fig=plt.figure(figsize=(10, 10))

ax = fig.add_subplot(1,1,1)
ax.scatter(np.arange(len(y)),y)

plt.errorbar(np.arange(len(y)), y, yerr=ey, fmt='o')

plt.show()

# %% [markdown]
# ### Gráfico para estudiante con nota 7:

# %%
z = np.array(datos_7)
dz=[0.4,  0.4,  0.4,  0.4,  0.4, 0.4, 0.4, 0.4]# 4mm en cm 
ez=np.array(dz)
    

fig=plt.figure(figsize=(10, 10))

ax = fig.add_subplot(1,1,1)
ax.scatter(np.arange(len(z)),z)

plt.errorbar(np.arange(len(z)), z, yerr=ez, fmt='o')

plt.show()

# %% [markdown]
# En resumen:

# %% [markdown]
# Pues, yo les pondría al revés, al que midio $0,3cm$ le pongo un 1. No puede medir eso si la sensibilidad de su instrumento es de $4mm=0.4cm$. Así que le pondría 7 al de 1 y 1 al de 7.

# %% [markdown]
# # Calificación: 6.0

# %% [markdown]
# El código está bien pero la conclusión no. La medida de $0.3$ cm del segundo estudiante sencillamente quiere decir que es compatible con cero dado el error del instrumento. Pero es posible que el instrumento haya dado ese número (no sabemos qué instrumento es).
#
# Por otra parte, el primer estudiante tiene mediciones demasiado perfectas, que se ajustan perfectamente a una parábola. Eso no es compatible con el hecho de tener un error. Claramente los datos son falsificados.
